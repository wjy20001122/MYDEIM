# %%
export OMP_NUM_THREADS=1

# 训练 YOLOv8n
yolo detect train cfg=/root/MYDEIM/configs/deimv2/yolov8n_pest.yaml device=0

# 训练 YOLOv10n
yolo detect train cfg=/root/MYDEIM/configs/deimv2/yolov10n_pest.yaml device=0

# 训练 YOLO12n
yolo detect train cfg=/root/MYDEIM/configs/deimv2/yolo12n_pest.yaml device=0
